# %% [markdown]
# # Project 10 - Spotify & YouTube Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"D:\Python\Project 10\10. Spotify_Youtube Dataset.csv")

# %%
data
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
#removing the column from the dataframe
data.drop(columns = ['Unnamed: 0', 'Url_spotify', 'Uri', 'Url_youtube'], inplace = True)

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
# Filling the missing values with 0 in lines & comments column
data['Likes'] = data['Likes'].fillna(0)
data['Comments'] = data['Comments'].fillna(0)

# %%
data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Title               470
# Channel             470
# Views               470
# Likes                 0
# Comments              0
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# # 1. Top Artist - with the Highest Views on YouTube?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
data.groupby('Artist')['Views'].sum()
# Out:
# Artist
# $NOT              1.107849e+08
# $uicideboy$       3.341351e+08
# (G)I-DLE          1.754954e+09
# *NSYNC            1.027833e+09
# 070 Shake         9.609936e+07
#                       ...
# will.i.am         2.831320e+09
# Ángela Aguilar    1.385295e+09
# Ñejo              6.266808e+08
# Ñengo Flow        8.127263e+08
# Øneheart          3.462331e+07
# Name: Views, Length: 2079, dtype: float64

# %%
Artist_grouped = data.groupby('Artist')['Views'].sum()

# %%
sorted_artist = Artist_grouped.sort_values(ascending = False)

# %%
sorted_artist.head(10)
# Out:
# Artist
# Ed Sheeran                 1.546021e+10
# CoComelon                  1.460167e+10
# Katy Perry                 1.312063e+10
# Charlie Puth               1.216759e+10
# Luis Fonsi                 1.162811e+10
# Justin Bieber              1.099106e+10
# Daddy Yankee               1.087193e+10
# Bruno Mars                 1.024092e+10
# Macklemore & Ryan Lewis    1.012206e+10
# Coldplay                   9.997278e+09
# Name: Views, dtype: float64

# %% [markdown]
# # 2. Top 10 Tracks - with the Highest Streams on Spotify?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
x = data[['Track', 'Stream']]
x
# Out:
#                                                Track        Stream
# 0                                     Feel Good Inc.  1.040235e+09
# 1                                    Rhinestone Eyes  3.100837e+08
# 2      New Gold (feat. Tame Impala and Bootie Brown)  6.306347e+07
# 3                                 On Melancholy Hill  4.346636e+08
# 4                                     Clint Eastwood  6.172597e+08
# ...                                              ...           ...
# 20713                           JUST DANCE HARDSTYLE  9.227144e+06
# 20714                 SET FIRE TO THE RAIN HARDSTYLE  1.089818e+07
# 20715                      OUTSIDE HARDSTYLE SPED UP  6.226110e+06
# 20716                            ONLY GIRL HARDSTYLE  6.873961e+06
# 20717                             MISS YOU HARDSTYLE  5.695584e+06
#
# [20718 rows x 2 columns]

# %%
x.sort_values(by = 'Stream', ascending = False)
# Out:
#                                                Track        Stream
# 15250                                Blinding Lights  3.386520e+09
# 12452                                   Shape of You  3.362005e+09
# 19186                              Someone You Loved  2.634013e+09
# 17937                     rockstar (feat. 21 Savage)  2.594927e+09
# 17445  Sunflower - Spider-Man: Into the Spider-Verse  2.538330e+09
# ...                                              ...           ...
# 20703                       Imperfect Girl - Sped Up           NaN
# 20704                               Like I'm British           NaN
# 20705                    ONLY NEED MY BABY! (SMOAGT)           NaN
# 20706                   HOW YOU ALWAYS LOOK SO GOOD?           NaN
# 20707                           Runaway (Move Quick)           NaN
#
# [20718 rows x 2 columns]

# %%
highest_streamed_track = x.sort_values(by = 'Stream', ascending = False)

# %%
highest_streamed_track.head(10)
# Out:
#                                                Track        Stream
# 15250                                Blinding Lights  3.386520e+09
# 12452                                   Shape of You  3.362005e+09
# 19186                              Someone You Loved  2.634013e+09
# 17937                     rockstar (feat. 21 Savage)  2.594927e+09
# 17445  Sunflower - Spider-Man: Into the Spider-Verse  2.538330e+09
# 17938  Sunflower - Spider-Man: Into the Spider-Verse  2.538330e+09
# 13503                                      One Dance  2.522432e+09
# 16099                                         Closer  2.456205e+09
# 16028                                         Closer  2.456205e+09
# 14030                                       Believer  2.369272e+09

# %% [markdown]
# # 3. 5 Tracks with the Lowest streams on Spotify?

# %%
lowest_streamed_track = x.sort_values(by='Stream', ascending = True)
lowest_streamed_track.head(5)
# Out:
#                                                   Track   Stream
# 8701                                           Rainbows   6574.0
# 3774                     We Play the Funk - Slynk Remix   7771.0
# 5161  Teil 9 - Sherlock Holmes und ein Brief von der...   8053.0
# 5160  Teil 10 - Sherlock Holmes und ein Brief von de...   8074.0
# 5159  Teil 5 - Sherlock Holmes und der blinde Bettle...  10306.0

# %% [markdown]
# # 4. What are the most common album types on Spotify? How many tracks belong to each album type?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
data['Album_type'].value_counts() #album is the most common album_type
# Out:
# Album_type
# album          14926
# single          5004
# compilation      788
# Name: count, dtype: int64

# %%
a_type = data['Album_type'].value_counts()
a_type
# Out:
# Album_type
# album          14926
# single          5004
# compilation      788
# Name: count, dtype: int64

# %%
#draw a pie chart

# %%
plt.pie(a_type, labels = a_type.index, autopct = "'%1.1f%%'", startangle = 60,
        colors = 'myr', shadow = 'True', explode = (0.05, 0.05, 0.5))
plt.show()

#explode - to cut the slices out
# autopct - to shoe the % on the chart using string format
# pctdistance = distance of % from center

# %% [markdown]
# # 5. How do the average views, likes, comments are compared between different album types ?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
data.groupby('Album_type')[['Views', 'Likes', 'Comments']].mean()
# Out:
#                     Views          Likes      Comments
# Album_type
# album        9.842739e+07  638515.020836  27458.547099
# compilation  7.961832e+07  496613.412437  16532.055838
# single       8.269886e+07  691931.659472  26300.293765

# %%
df = data.groupby('Album_type')[['Views', 'Likes', 'Comments']].mean()
df
# Out:
#                     Views          Likes      Comments
# Album_type
# album        9.842739e+07  638515.020836  27458.547099
# compilation  7.961832e+07  496613.412437  16532.055838
# single       8.269886e+07  691931.659472  26300.293765

# %%
df = df.reset_index()
df
# Out:
#     Album_type         Views          Likes      Comments
# 0        album  9.842739e+07  638515.020836  27458.547099
# 1  compilation  7.961832e+07  496613.412437  16532.055838
# 2       single  8.269886e+07  691931.659472  26300.293765

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#melt = unpivot a dataframe
pd.melt(df, id_vars = 'Album_type', var_name = "Attribute", value_name = 'Total')

# we melted this because it will be easier to make bar plot
df_melted = pd.melt(df, id_vars = 'Album_type', var_name = "Attribute", value_name = 'Total')
df_melted
# Out:
#     Album_type Attribute         Total
# 0        album     Views  9.842739e+07
# 1  compilation     Views  7.961832e+07
# 2       single     Views  8.269886e+07
# 3        album     Likes  6.385150e+05
# 4  compilation     Likes  4.966134e+05
# 5       single     Likes  6.919317e+05
# 6        album  Comments  2.745855e+04
# 7  compilation  Comments  1.653206e+04
# 8       single  Comments  2.630029e+04

# %%
# draw the bar plot
plt.figure(figsize = (9,4))
sns.barplot(x = 'Album_type', y = 'Total', hue = 'Attribute', data = df_melted);

# %% [markdown]
# # 6. Top 5 youtube channel - based on the views?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
c_views = data.groupby('Channel')['Views'].sum().sort_values(ascending = False).head()
c_views
# Out:
# Channel
# T-Series            4.796159e+10
# LuisFonsiVEVO       2.170252e+10
# CalvinHarrisVEVO    1.828114e+10
# Macklemore          1.700341e+10
# Ed Sheeran          1.691822e+10
# Name: Views, dtype: float64

# %%
c_views = c_views.reset_index()
c_views
# Out:
#             Channel         Views
# 0          T-Series  4.796159e+10
# 1     LuisFonsiVEVO  2.170252e+10
# 2  CalvinHarrisVEVO  1.828114e+10
# 3        Macklemore  1.700341e+10
# 4        Ed Sheeran  1.691822e+10

# %%
type(c_views)
# Out:
# pandas.core.frame.DataFrame

# %%
#sns.set_style("Whitegrid")
sns.barplot(x = "Views", y = "Channel", data = c_views)
plt.title('Top 5 Viewed Channel')
plt.xlabel("Views")
plt.ylabel("Channel")
plt.show()

# %% [markdown]
# # 7. Top most Track based on views?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
top_viewed_track = data.groupby('Track')['Views'].sum().sort_values(ascending = False).head(3)
top_viewed_track
# Out:
# Track
# Despacito                             1.615930e+10
# See You Again (feat. Charlie Puth)    1.154760e+10
# Lean On                               9.974505e+09
# Name: Views, dtype: float64

# %%
#another way
data.sort_values(by = 'Views', ascending = False).head(1)
# Out:
#           Artist      Track Album Album_type  Danceability  Energy  Key  \
# 1147  Luis Fonsi  Despacito  VIDA      album         0.655   0.797  2.0
#
#       Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 1147    -4.787        0.153         0.198  ...     229360.0
#
#                                         Title        Channel         Views  \
# 1147  Luis Fonsi - Despacito ft. Daddy Yankee  LuisFonsiVEVO  8.079649e+09
#
#            Likes   Comments  \
# 1147  50788652.0  4252791.0
#
#                                             Description  Licensed  \
# 1147  “Despacito” disponible ya en todas las platafo...      True
#
#       official_video        Stream
# 1147            True  1.506598e+09
#
# [1 rows x 24 columns]

# %% [markdown]
# # 8. Whihc top 7 tracks have the highest like-to-view ratio on Youtube?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
track_lv_ratio = data[['Track', 'Likes', 'Views']]
track_lv_ratio
# Out:
#                                                Track      Likes        Views
# 0                                     Feel Good Inc.  6220896.0  693555221.0
# 1                                    Rhinestone Eyes  1079128.0   72011645.0
# 2      New Gold (feat. Tame Impala and Bootie Brown)   282142.0    8435055.0
# 3                                 On Melancholy Hill  1788577.0  211754952.0
# 4                                     Clint Eastwood  6197318.0  618480958.0
# ...                                              ...        ...          ...
# 20713                           JUST DANCE HARDSTYLE     1113.0      71678.0
# 20714                 SET FIRE TO THE RAIN HARDSTYLE     2019.0     164741.0
# 20715                      OUTSIDE HARDSTYLE SPED UP      329.0      35646.0
# 20716                            ONLY GIRL HARDSTYLE       88.0       6533.0
# 20717                             MISS YOU HARDSTYLE     2484.0     158697.0
#
# [20718 rows x 3 columns]

# %%
track_lv_ratio['LV_Ration'] = data['Likes']/data['Views'] * 100
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_20992\2226073704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   track_lv_ratio['LV_Ration'] = data['Likes']/data['Views'] * 100

# %%
track_lv_ratio
# Out:
#                                                Track      Likes        Views  \
# 0                                     Feel Good Inc.  6220896.0  693555221.0
# 1                                    Rhinestone Eyes  1079128.0   72011645.0
# 2      New Gold (feat. Tame Impala and Bootie Brown)   282142.0    8435055.0
# 3                                 On Melancholy Hill  1788577.0  211754952.0
# 4                                     Clint Eastwood  6197318.0  618480958.0
# ...                                              ...        ...          ...
# 20713                           JUST DANCE HARDSTYLE     1113.0      71678.0
# 20714                 SET FIRE TO THE RAIN HARDSTYLE     2019.0     164741.0
# 20715                      OUTSIDE HARDSTYLE SPED UP      329.0      35646.0
# 20716                            ONLY GIRL HARDSTYLE       88.0       6533.0
# 20717                             MISS YOU HARDSTYLE     2484.0     158697.0
#
#        LV_Ration
# 0       0.896958
# ...

# %%
track_lv_ratio.sort_values(by = 'LV_Ration', ascending = False).head(7)
# Out:
#                               Track     Likes      Views  LV_Ration
# 19968                         Intro  237761.0   954081.0  24.920421
# 19969                   Safety Zone  453910.0  1952637.0  23.246000
# 19967                        Future  250116.0  1180522.0  21.186899
# 19971                 Pandora's Box  253702.0  1265231.0  20.051832
# 12193                     Resistiré       9.0       49.0  18.367347
# 16297  My Universe - Galantis Remix  371437.0  2067753.0  17.963316
# 15065           Burn It (feat. MAX)  188244.0  1054438.0  17.852543

# %% [markdown]
# # 9. Which top 3 tracks have the lowest like-to-view ratio on Youtube?

# %%
track_lv_ratio.sort_values(by = 'LV_Ration', ascending = True).head(3)
# Out:
#                                 Track  Likes       Views  LV_Ration
# 3136                    Hey - Spanish    0.0    706285.0        0.0
# 4865  Head, Shoulders, Knees and Toes    0.0  20572365.0        0.0
# 6799         Vocalise, Op. 34, No. 14    0.0    133439.0        0.0

# %% [markdown]
# # 10. Top album having the tracks with maximum Danceability ?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0  6.0    -6.679       0.1770       0.00836  ...     222640.0
# 1  8.0    -5.815       0.0302       0.08690  ...     200173.0
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# ...

# %%
T_danceability = data.groupby('Album')['Danceability'].sum().sort_values(ascending = False)
T_danceability
# Out:
# Album
# Hamilton (Original Broadway Cast Recording)                                                19.349
# Greatest Hits                                                                              18.463
# Rebelde                                                                                    15.365
# HEROES & VILLAINS                                                                          14.300
# RODZINNY BIZNES                                                                            13.491
#                                                                                             ...
# Hello, Dolly! (Remastered)                                                                  0.000
# Soothing Rain for Background Sounds and Natural White Noise                                 0.000
# The Three Tenors - The Best of the 3 Tenors                                                 0.000
# ...

# %%
data[data.Album == 'Greatest Hits']
# Out:
#                                 Artist  \
# 220                               2Pac
# 222                               2Pac
# 225                               2Pac
# 268                      Fleetwood Mac
# 1232                 Bruce Springsteen
# 1236                 Bruce Springsteen
# 1862                      Shania Twain
# 2164                       Wyclef Jean
# 3079                     Tracy Chapman
# 3097                           Blondie
# 3147                      Willie Colón
# 3578                        Eurythmics
# 3579                        Eurythmics
# 3580                        Eurythmics
# 3598                       Snow Patrol
# 3836                      James Taylor
# 3842                      James Taylor
# 4324   Tom Petty and the Heartbreakers
# 5031                            Fugees
# 5185                    Gloria Estefan
# 6721                           Kenny G
# 7088                             Björk
# 8434                      Annie Lennox
# ...

# %% [markdown]
# # 11. What is the Correlation between Views, Likes, comments and stream ?

# %%
df_vlcs = data[['Views', 'Likes', 'Comments', 'Stream']]

# %%
df_vlcs
# Out:
#              Views      Likes  Comments        Stream
# 0      693555221.0  6220896.0  169907.0  1.040235e+09
# 1       72011645.0  1079128.0   31003.0  3.100837e+08
# 2        8435055.0   282142.0    7399.0  6.306347e+07
# 3      211754952.0  1788577.0   55229.0  4.346636e+08
# 4      618480958.0  6197318.0  155930.0  6.172597e+08
# ...            ...        ...       ...           ...
# 20713      71678.0     1113.0       0.0  9.227144e+06
# 20714     164741.0     2019.0       0.0  1.089818e+07
# 20715      35646.0      329.0       0.0  6.226110e+06
# 20716       6533.0       88.0       0.0  6.873961e+06
# 20717     158697.0     2484.0       0.0  5.695584e+06
#
# [20718 rows x 4 columns]

# %%
df_vlcs.corr()
# Out:
#              Views     Likes  Comments    Stream
# Views     1.000000  0.891073  0.431159  0.601905
# Likes     0.891073  1.000000  0.631231  0.652048
# Comments  0.431159  0.631231  1.000000  0.266854
# Stream    0.601905  0.652048  0.266854  1.000000

# %%
sns.heatmap(df_vlcs.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Thankyou !
